# %% [markdown]
# # Ejercicio Clase 4

# %% [markdown]
# ![Topologia_Ejercicio_clase_4.JPG](attachment:Topologia_Ejercicio_clase_4.JPG)

# %% [markdown]
# $V2=\frac{I3}{sC2} => I3=V2.sC2$  (1)
#
# $ I3 = Vc1.gm3$       (2)
#
# $VC1=(I1+I2+I3).\frac{1}{sC1}$ (3)
#
# (3)en (2) $I3=(I1+I2+I3).\frac{gm3}{sC1}$ (4)
#
# (1) en (4) $V2.sC2 = (I1+I2+I3)\frac{gm3}{sC1}$
#
# $V2.\frac{s^{2}C2C1}{gm3}=V1.gm1+Vc1.gm2+V2.gm4$ (5)
#
# de (1) $V2=\frac{Vc1.gm3}{sC2} => Vc1=V2.\frac{sC2}{gm3}$
#
# Remplazo en (5)  $V2.\frac{s^{2}C2C1}{gm3} = V1.gm1+V2.\frac{sC2.gm2}{gm3}+V2.gm4$
#
# $V2.(\frac{s^{2}C2C1+sC2+gm4.gm3}{gm2})=V1.gm1$
#
# $\frac{V2}{V1}= \frac{\frac{gm1.gm3}{C2C1}}{s^{2}+\frac{s.gm2}{C1}+\frac{gm4.gm3}{C2C1}}$
#
# $\frac{V2}{V1}= \frac{\frac{gm1}{gm4}.\frac{gm4.gm3}{C2C1}}{s^{2}+\frac{s.gm2}{C1}+\frac{gm4.gm3}{C2C1}}$
#
# Comparando $Ts=\frac{wo^{2}}{s^{2}+s\frac{wo}{Q}+wo^{2}}$
#
# $wo^{2}=\frac{gm4.gm3}{C2C1} $
#
# $K=\frac{gm1}{gm4}$
#
# $ \frac{V2}{V1}=\frac{ K.wo^{2}}{s^{2}+s.\frac{gm2}{C1}+\frac{gm4.gm3}{C2C1}}$

# %% [markdown]
# ### Conclusion
# #### Diseñamos a partir de los parametro wo, Q, K
