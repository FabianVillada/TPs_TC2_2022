# %% [markdown]
# Trabajo practico TC2
#
# $V(x)= \frac{V1.R3}{R3 + \frac {1}{SC}} =>  V(x)= \frac{V1.SCR3}{SCR3 +1}$  (1)
#
# $ \frac{V(x)-V2}{R2}=\frac{V(1)-V(x)}{R1}$ => $V(x)=\frac{V1.R2+V2.R1}{(R1+R2)}$ (2)
#
# (1)=(2) -> $\frac{V1.R2+V2.R1}{R1+R2}=V1.\frac{sCR3}{sC.R3+1}$
#
# operando
#
# $\frac{V2}{V1}=\frac{sCR3}{sCR3+1}.\frac{R1+R2}{R1} - \frac{R2}{R1}$
#
# $\frac{V2}{V1}=\frac{s-\frac{R2}{CR3R1)}}{s+\frac{1}{R3C}}$
#
# Considero $\omega o=\frac{1}{R3C}  =>  \frac{V2}{V1}=\frac{s- wo.\frac{R2}{R1}}{s+wo}$ (3)
#
# Dominio jw
#
# $\frac{V2}{V1}(j\omega)=\frac{j\omega-\frac{R2}{R1}.\omega_o}{j\omega+\omega_o}$
#
# $|\frac{V2}{V1}|²= \frac{\omega²+(\frac{R2}{R1}.\omega_o)²}{\omega²+\omega_o²}$
#
# $\phi= arctg(\frac{\omega}{-\frac{R2}{R1}.\omega_o})-arctg(\frac{\omega}{\omega_o})$

# %% [markdown]
# Normalizacion
#
# $sn=\frac{s}{\omega o}$
#
# remplazando en (3)
#
# $\frac{V2}{V1}=\frac{sn.\omega o - \omega o.\frac{R2}{R1}}{sn.\omega o + \omega o} =>  \frac{V2}{V1}=\frac{sn - \frac{R2}{R1}}{sn + 1}$

# %% [markdown]
# ## Simulacion Numerica con Python

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sig
from splane import analyze_sys, pretty_print_bicuad_omegayq

num = np.array([1,-1]) 
den = np.array([1,1])

pretty_print_bicuad_omegayq(num,den)

mi_sos = sig.TransferFunction(num,den)

plt.close('all')
analyze_sys(mi_sos, 'mi SOS')
# Out:
# $\displaystyle \frac{s +  -1 }{s^2 + s \frac{  1}{  1} +   1^2}$

# %% [markdown]
# ## Simulacion Circuital LTspice

# %%
<img src="LTspice_TS1.jpg">
