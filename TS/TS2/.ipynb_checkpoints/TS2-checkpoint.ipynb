# %% [markdown]
# ## Teoria de Circuitos 2
#
# # TAREA SEMANAL 2

# %% [markdown]
#  <div class="alert alert-block alert-success"><b> Analis de Transferencia por metodo de nodos y Valores de componentes para wo=1 Q=3</b> </div>

# %% [markdown]
# ![TS2_1](TS2_1.jpeg)

# %% [markdown]
# ![TS2_2](TS2_2.jpeg)

# %% [markdown]
#  <div class="alert alert-block alert-success"><b> Simulacion LTspice para wo=1 y Q=3</b> </div>

# %% [markdown]
# ![SimTS2_1](SimTS2_1.JPG)

# %% [markdown]
#  <div class="alert alert-block alert-success"><b> Red Normalizada Sn=wo*s y Rn=R3  </b> </div>

# %% [markdown]
# ![TS_3](TS_3.jpeg)

# %% [markdown]
#  <div class="alert alert-block alert-success"><b> Aproximacion por Buttreworth.</b> </div>

# %% [markdown]
# ##### Segun lo visto en la teoria para una aproximacio Butterworth:

# %% [markdown]
# $Q=\frac{1}{2.\cos\alpha}$
#
# $\alpha=\frac{\pi}{4}$
#
# $Q=\frac{1}{\cos\frac{\pi}{4}}$
#
# $\bbox[orange, 8px]{Q=0.707}$
#
# $Q=\frac{R2}{R3}$  ; $R3=1M$   ; $c=1uF$
#
# $\bbox[green,8px]{R2=707K}$

# %% [markdown]
# #### Es interesante adelantar como conclusion la posibilidad de modificar Q controlando R2 y modificar la ganancia controlando R1

# %% [markdown]
#  <div class="alert alert-block alert-success"><b> Simulacion circuital normalizada en LTspice parametrizando R2 del cual depende Q </b> </div>

# %% [markdown]
# ![SimTS2_2](SimTS2_2.JPG)

# %% [markdown]
#  <div class="alert alert-block alert-success"><b> Simulacion Numerica normalizada en Python parametrizando Q , Representacio Polos y retardo de grupo</b> </div>

# %%
#Created on Mon Apr 11 04:13:44 2022

 #SIMULACION Tarea Semanal 2

#A= - K (1/s^2+s(1/Q)+1)

#Con K=1 -> R3=R2

#@author: Fabian


import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sig
from splane import analyze_sys, pretty_print_bicuad_omegayq

K=1

Q = [4, 2, 1, 0.707]

plt.close('all')

for i in range(len(Q)):
    
    num = np.array([K*1]) 
    den = np.array([1,1/Q[i],1])

    pretty_print_bicuad_omegayq(num,den)
    
    mi_sos = sig.TransferFunction(num,den)
    
    if i==0:
        analyze_sys(mi_sos, 'Q=4')
    
    elif i==1:
        analyze_sys(mi_sos, 'Q=2')
        
    elif i==2:
        analyze_sys(mi_sos, 'Q=1')

    elif i==3:
        analyze_sys(mi_sos, 'Q=0.707')
# Out:
# $\displaystyle \frac{  1 }{s^2 + s \frac{  1}{  4} +   1^2}$
# $\displaystyle \frac{  1 }{s^2 + s \frac{  1}{  2} +   1^2}$
# $\displaystyle \frac{  1 }{s^2 + s \frac{  1}{  1} +   1^2}$
# $\displaystyle \frac{  1 }{s^2 + s \frac{  1}{0.707} +   1^2}$
